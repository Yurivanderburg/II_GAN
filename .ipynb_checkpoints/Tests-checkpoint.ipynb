# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from scipy import fft, ndimage
import cv2

# %%
img = mpimg.imread('Data/SpiralGalaxy/apod_2023-08-11.jpg') # Full image

# %%
def plotHist(img):
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.axis('off')
    hist = plt.subplot(1,2,2)
    hist.set_ylabel('Count')
    hist.set_xlabel('Pixel Intensity')
    plt.hist(img.flatten(), bins=10, lw=0, alpha=0.5, color='r')

# %%
def plot_fft(img):
    img_grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_fft = fft.fftshift(fft.fft2(fft.fftshift(img_grayscale)))
    display = np.log(np.abs(img_fft))
    plt.imshow(display/np.max(display))

# %%
plotHist(img)

# %%
plot_fft(img)

# %%
# Rescaling tests

# %%
image_size = 64 #px

# %%
res = cv2.resize(img, dsize=(image_size, image_size), interpolation=cv2.INTER_AREA)
res.shape
# Out:
# (64, 64, 3)

# %%
plt.imshow(res)

# %%
plot_fft(res)
