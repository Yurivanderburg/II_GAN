# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import numpy as np
from scipy import fft, ndimage
import cv2

# %%
img = mpimg.imread('Data/siriusb_cxo_big.jpg') # Full image

# %%
def plotHist(img):
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    plt.imshow(img)
    plt.axis('off')
    hist = plt.subplot(1,2,2)
    hist.set_ylabel('Count')
    hist.set_xlabel('Pixel Intensity')
    plt.hist(img.flatten(), bins=10, lw=0, alpha=0.5, color='r')

# %%
img_rgb[:,:,0]
# Out:
# array([[ 1,  1,  1, ...,  0,  0,  0],
#        [ 2,  1,  1, ...,  0,  1,  1],
#        [ 2,  2,  1, ...,  0,  1,  2],
#        ...,
#        [16, 11,  5, ...,  0,  1,  2],
#        [26, 15,  5, ...,  1,  1,  2],
#        [26, 15,  5, ...,  1,  1,  2]], dtype=uint8)

# %%
print(img.shape)
# Out:
# (810, 1024, 3)

# %%
plt.imshow(img)

# %%
# Grayscale imge - only 1 channel
img_grayscale = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_grayscale, cmap='Greys')
img_grayscale.shape
# Out:
# (810, 1024)

# %%
# Fourier transform 2D -> Spatial power spectrum
img_fft = fft.fft2(img_grayscale)

# %%
# Plot FFT2D of image, required log scale
plt.imshow(np.log(np.abs(img_fft)))

# %%
# Check inverse fft:
inverse = fft.ifft2(img_fft)
plt.imshow(abs(inverse),cmap='Greys')
